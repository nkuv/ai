# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/Colab/assets/tigergrey.jpeg', 0)

equalized = cv2.equalizeHist(img)

cv2_imshow(img)
cv2_imshow(equalized)
# Out:
# <PIL.Image.Image image mode=L size=187x148>
# <PIL.Image.Image image mode=L size=187x148>

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.title('Histogram Before Equalization')
plt.hist(img.ravel(), bins=256, range=[0,256], color='blue')
plt.xlim([0,256])

plt.subplot(1,2,2)
plt.title('Histogram After Equalization')
plt.hist(equalized.ravel(), bins=256, range=[0,256], color='blue')
plt.xlim([0,256])

plt.show()
