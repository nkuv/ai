# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/Colab/assets/tigergrey.jpeg',0)
log_img = np.uint8(255 * (np.log1p(img.astype(np.float64)) / np.log1p(img.max())))

cv2_imshow(img)
cv2_imshow(log_img)
# Out:
# <PIL.Image.Image image mode=L size=187x148>
# <PIL.Image.Image image mode=L size=187x148>
