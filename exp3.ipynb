# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('assets/tiger.jpeg')

tx, ty = 100, 50
rows, cols = img.shape[:2]
translation_matrix = np.float32([[1, 0, tx], [0, 1, ty]])
translated_img = cv2.warpAffine(img, translation_matrix, (cols, rows))

scaled_img = cv2.resize(img, None, fx=0.5, fy=0.5)

angle = 45
rotation_matrix = cv2.getRotationMatrix2D((cols/2, rows/2), angle, 1)
rotated_img = cv2.warpAffine(img, rotation_matrix, (cols, rows))

cv2_imshow(img)
cv2_imshow(translated_img)
cv2_imshow(scaled_img)
cv2_imshow(rotated_img)
# Out:
# <PIL.Image.Image image mode=RGB size=187x148>
# <PIL.Image.Image image mode=RGB size=187x148>
# <PIL.Image.Image image mode=RGB size=94x74>
# <PIL.Image.Image image mode=RGB size=187x148>
