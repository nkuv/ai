# %%
import cv2
from google.colab import drive
from matplotlib import pyplot as plt

image_path = "/content/drive/MyDrive/Colab/assets/binaryimage"
img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)


print(f"Image shape: {img.shape}")
print(f"Image dtype: {img.dtype}")
# Out:
# Image shape: (224, 224, 3)
# Image dtype: uint8

# %%
if len(img.shape) == 2:
    neg = 255 - img

elif len(img.shape) == 3:
    height, width, channels = img.shape
    neg = img.copy()
    for y in range(height):
        for x in range(width):
            b, g, r = img[y, x]
            neg[y, x] = [255 - b, 255 - g, 255 - r]


plt.subplot(1, 2, 1)
if len(img.shape) == 2:
    plt.imshow(img, cmap='gray')
else:
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')


plt.subplot(1, 2, 2)
if len(neg.shape) == 2:
    plt.imshow(neg, cmap='gray')
else:
    plt.imshow(cv2.cvtColor(neg, cv2.COLOR_BGR2RGB))
    plt.title("Negative Image")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
image_path = "/content/drive/MyDrive/Colab/assets/tigerbinary.jpeg"
img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)


print(f"Image shape: {img.shape}")
print(f"Image dtype: {img.dtype}")
# Out:
# Image shape: (148, 187)
# Image dtype: uint8

# %%
if len(img.shape) == 2:
    neg = 255 - img

elif len(img.shape) == 3:
    height, width, channels = img.shape
    neg = img.copy()
    for y in range(height):
        for x in range(width):
            b, g, r = img[y, x]
            neg[y, x] = [255 - b, 255 - g, 255 - r]


plt.subplot(1, 2, 1)
if len(img.shape) == 2:
    plt.imshow(img, cmap='gray')
else:
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')


plt.subplot(1, 2, 2)
if len(neg.shape) == 2:
    plt.imshow(neg, cmap='gray')
else:
    plt.imshow(cv2.cvtColor(neg, cv2.COLOR_BGR2RGB))
    plt.title("Negative Image")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
image_path = "/content/drive/MyDrive/Colab/assets/tiger.jpeg"
img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)


print(f"Image shape: {img.shape}")
print(f"Image dtype: {img.dtype}")
# Out:
# Image shape: (148, 187, 3)
# Image dtype: uint8

# %%
if len(img.shape) == 2:
    neg = 255 - img

elif len(img.shape) == 3:
    height, width, channels = img.shape
    neg = img.copy()
    for y in range(height):
        for x in range(width):
            b, g, r = img[y, x]
            neg[y, x] = [255 - b, 255 - g, 255 - r]


plt.subplot(1, 2, 1)
if len(img.shape) == 2:
    plt.imshow(img, cmap='gray')
else:
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')


plt.subplot(1, 2, 2)
if len(neg.shape) == 2:
    plt.imshow(neg, cmap='gray')
else:
    plt.imshow(cv2.cvtColor(neg, cv2.COLOR_BGR2RGB))
    plt.title("Negative Image")
    plt.axis('off')

plt.tight_layout()
plt.show()
